# %%
#!{sys.executable} -m pip install numpy
#!{sys.executable} -m pip install matplotlib

# %%
import sys
# Out:
# Requirement already satisfied: numpy in /home/roman/my_project_dir/my_project_env/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /home/roman/my_project_dir/my_project_env/lib/python3.10/site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/roman/my_project_dir/my_project_env/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/roman/my_project_dir/my_project_env/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/roman/my_project_dir/my_project_env/lib/python3.10/site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/roman/my_project_dir/my_project_env/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /home/roman/my_project_dir/my_project_env/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/roman/my_project_dir/my_project_env/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /home/roman/my_project_dir/my_project_env/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/roman/my_project_dir/my_project_env/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/roman/my_project_dir/my_project_env/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/roman/my_project_dir/my_project_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from math import *
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
def f_1(x):
    return  5 * (np.sin(2*np.pi*10*x)/2*np.pi*10*x)*np.cos(2*np.pi)

# %%
y_cor = []
x_cor = []
for x in range(1,4+1):
    if x != 0:
        x_cor.append(x)
        y_cor.append(f_1(x))
        print(f_1(x))
# Out:
# 0.8414709848078965
# -0.3784012476539641
# 0.13737282841391887
# -0.07197582916626633

# %%
def df(x):
    return (2* np.cos(x**2) - np.sin(x**2))/(x**2)

# %%
for x in range(1,5):
    print(df(x))
# Out:
# 0.23913362692838303
# -1.1180866179002418
# -1.8680514665739936
# -1.8973250033552027

# %%
x_plt = np.arange(1, 4.1, 0.01)
f_plt  = [f_1(x) for x in x_plt]

fig, ax = plt.subplots()
ax.grid()
ax.plot(x_plt, f_plt)
plt.show()

# %%
x_plt = np.arange(1,4.1,0.01)
f_plt  = [df(x) for x in x_plt]

fig, ax = plt.subplots()
ax.grid()
ax.plot(x_plt, f_plt)
plt.show()

# %%
x_0 = 3
y = f_1(x_0)

# %%
for _ in range(0,50):
    y = y  - df(x_0)
    print(y)
# Out:
# 2.0054242949879124
# 3.873475761561906
# 5.741527228135899
# 7.609578694709892
# 9.477630161283885
# 11.345681627857878
# 13.213733094431872
# 15.081784561005865
# 16.94983602757986
# 18.817887494153855
# 20.68593896072785
# 22.553990427301844
# 24.42204189387584
# 26.290093360449834
# 28.15814482702383
# 30.026196293597824
# 31.89424776017182
# 33.76229922674581
# 35.630350693319805
# 37.4984021598938
# 39.366453626467795
# 41.23450509304179
# 43.102556559615785
# 44.97060802618978
# 46.838659492763774
# 48.70671095933777
# 50.574762425911764
# 52.44281389248576
# 54.310865359059754
# 56.17891682563375
# 58.046968292207744
# 59.91501975878174
# 61.783071225355734
# 63.65112269192973
# 65.51917415850372
# 67.3872256250777
# 69.25527709165169
# 71.12332855822568
# 72.99138002479967
# 74.85943149137366
# 76.72748295794764
# 78.59553442452163
# 80.46358589109562
# 82.3316373576696
# 84.1996888242436
# 86.06774029081758
# 87.93579175739157
# 89.80384322396556
# 91.67189469053955
# 93.53994615711353

# %% [markdown]
# # Градиентный спуск

# %%
def min_f(len_, it):
    x = 1.5
    for _ in range(it):
        grad = df(x)
        x = x - 0.1 *grad
    print(f(x))

# %%
min_f(0.01,100)
# Out:
# -0.27560715896661153

# %%
x = np.linspace(1, 4, 1000)  # Задаем интервал значений x

y = df(x)  # Вычисляем значения функции в заданных точках


grad_y = np.gradient(y, x)  # Вычисляем градиент функции
f = 0 
for i in grad_y:
    if i <f:
        f = i
print(f)
# print(grad_y)

fig, ax = plt.subplots()
ax.grid()
ax.plot(x, grad_y)
plt.show()
# Out:
# -4.904065955481811

# %%
x_plt = x
f_plt  = [df(x) for x in x_plt]

fig, ax = plt.subplots()
ax.grid()
ax.plot(x_plt, f_plt)
plt.show()
